# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ----

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# PROJECT_ROOT

# %%
from fliptop import RAW_DATA_DIR
from fliptop.data_cleaning import build_df_battles

# %%
# Build data from local sources
df_battles = build_df_battles(raw_dir=RAW_DATA_DIR)

# %%
# from IPython.display import HTML

# HTML(
#     '<div style="height:600px; overflow:auto; border:1px solid #ccc">'
#     + df_battles.to_html(index=False)
#     + "</div>"
# )

# %%
df_battles.head(5)
# Out:
#             id  ...                                          url
# 0  RFU9nhvgxaM  ...  https://www.youtube.com/watch?v=RFU9nhvgxaM
# 1  LlbgujCVl60  ...  https://www.youtube.com/watch?v=LlbgujCVl60
# 2  aDBnSKEPQOY  ...  https://www.youtube.com/watch?v=aDBnSKEPQOY
# 3  iReYgDruGEM  ...  https://www.youtube.com/watch?v=iReYgDruGEM
# 4  NumdcFwxvm0  ...  https://www.youtube.com/watch?v=NumdcFwxvm0
#
# [5 rows x 13 columns]
