# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ----

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# PROJECT_ROOT

# %%
from fliptop import RAW_DATA_DIR
from fliptop.data_cleaning import build_df_battles
from fliptop.emcee_table import build_emcees_table, write_emcees_table

# %%
# Build data from local sources
df_battles = build_df_battles(raw_dir=RAW_DATA_DIR)

# %%
# from IPython.display import HTML

# HTML(
#     '<div style="height:600px; overflow:auto; border:1px solid #ccc">'
#     + df_battles.to_html(index=False)
#     + "</div>"
# )

# %%
df_battles.head(5)
# Out:
#             id                               title  \
# 0  SXT0FqertLI         FlipTop - K-Ram vs Empithri
# 1  RFU9nhvgxaM  FlipTop - Jonas vs Emar Industriya
# 2  LlbgujCVl60       FlipTop - Pistolero vs Harlem
# 3  aDBnSKEPQOY     FlipTop - Lord Manuel vs Kalixs
# 4  iReYgDruGEM         FlipTop - Hespero vs R-Zone
#
#                                          description         upload_date  \
# 0  FlipTop presents: Ahon 16 @ The Tent, Las Pina... 2026-03-04 12:08:12
# 1  FlipTop presents: Ahon 16 @ The Tent, Las Pina... 2026-02-28 13:26:09
# 2  FlipTop presents: Ahon 16 @ The Tent, Las Pina... 2026-02-28 12:12:10
# 3  FlipTop presents: Zoning 20 @ Matchpoint Sport... 2026-02-28 11:33:05
# 4  FlipTop presents: Ahon 16 @ The Tent, Las Pina... 2026-02-19 12:40:15
#
#    duration_seconds duration_hms       emcee1           emcee2  \
# 0            1923.0     00:32:03        K-Ram         Empithri
# 1            2363.0     00:39:23        Jonas  Emar Industriya
# 2            2145.0     00:35:45    Pistolero           Harlem
# 3            1877.0     00:31:17  Lord Manuel           Kalixs
# 4            1681.0     00:28:01      Hespero           R-Zone
#
#                     matchup event_name event_date  \
# 0         K-Ram vs Empithri    Ahon 16 2025-12-13
# 1  Jonas vs Emar Industriya    Ahon 16 2025-12-13
# 2       Pistolero vs Harlem    Ahon 16 2025-12-13
# 3     Lord Manuel vs Kalixs  Zoning 20 2025-10-24
# 4         Hespero vs R-Zone    Ahon 16 2025-12-13
#
#                                       event_location  \
# 0  The Tent, Las Pinas City, Metro Manila, Philip...
# 1  The Tent, Las Pinas City, Metro Manila, Philip...
# 2  The Tent, Las Pinas City, Metro Manila, Philip...
# 3  Matchpoint Sports Bar, Mandaluyong City, Metro...
# 4  The Tent, Las Pinas City, Metro Manila, Philip...
#
#                                            url
# 0  https://www.youtube.com/watch?v=SXT0FqertLI
# 1  https://www.youtube.com/watch?v=RFU9nhvgxaM
# 2  https://www.youtube.com/watch?v=LlbgujCVl60
# 3  https://www.youtube.com/watch?v=aDBnSKEPQOY
# 4  https://www.youtube.com/watch?v=iReYgDruGEM

# %%
df_emcees = build_emcees_table(df_battles)

# %%
write_emcees_table(df_battles, "../data/processed/emcees.csv")
